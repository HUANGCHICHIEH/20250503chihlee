# %% [markdown]
# ###看老師的連結即可

# %%
import numpy as np

np.random.seed(567)
scores = np.random.randint(50, 101, size=(50, 5))
scores
# Out:
# array([[ 53,  97,  72,  94,  55],
#        [ 59,  66,  94,  83,  60],
#        [ 58,  76,  90,  99,  64],
#        [ 55,  83,  87,  76,  67],
#        [ 75,  84,  95,  68,  84],
#        [ 64,  64,  95,  66,  68],
#        [ 55,  62,  99,  57,  78],
#        [ 59,  66,  77,  59,  95],
#        [ 84,  76,  96,  85,  50],
#        [ 71,  68,  92,  67,  93],
#        [ 83,  55,  95,  62,  93],
#        [ 62,  71,  56,  50,  75],
#        [ 72,  94,  53,  94,  99],
#        [ 67, 100,  50,  85,  99],
#        [ 92,  60,  77,  59,  58],
#        [ 94,  90,  64,  57, 100],
#        [ 99,  99,  79,  99,  86],
#        [ 67,  74,  95,  65,  73],
#        [ 66,  91,  56,  59,  80],
#        [ 56,  67,  79,  79,  52],
#        [ 51,  91,  70,  65,  92],
#        [ 91,  77,  96,  83,  74],
#        [ 57,  89,  84,  57,  69],
#        [ 57,  67,  89,  97,  59],
#        [ 95,  69,  54,  56,  51],
#        [ 87,  64,  90,  68,  65],
#        [ 58,  53,  63,  82,  51],
# ...
