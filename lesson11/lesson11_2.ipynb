# %%
import numpy as np
from numpy import ndarray

students: ndarray = np.array([[78, 92, 68, 95, 91],
                              [65, 75, 63, 84, 86]])

students[0]#取得第1位學生資料
students[1]#取得第2位學生資料
students[1,:3]#取得第2位學生資料，前3科分數
students[0,-3:]#取得第1位學生資料，後3科分數
# Out:
# array([68, 95, 91])

# %%
subjects:list[str]=['chinest','english','math','history','discover']
subjects
# Out:
# ['chinest', 'english', 'math', 'history', 'discover']

# %%
figure=plt.figure()
axes1 = figure.add_subplot(3,1,1)
axes2 = figure.add_subplot(3,1,2)
axes3 = figure.add_subplot(3,1,3)

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes=figure.add_subplot()
axes.plot(subjects, students[0],label="stu1")
axes.plot(subjects, students[1],label="stu2")
axes.legend()
axes.set_title("stu1 vs stu 2")
axes.set_xlabel("subject",fontsize='large',color='c')
axes.set_ylabel("scores")
plt.savefig("plot1.png")
plt.show()
plt.close()
# Out:
# 在目前儲存格或上一個儲存格中執行程式碼時，Kernel 已損毀。
#
# 請檢閱儲存格中的程式碼，找出失敗的可能原因。
#
# 如需詳細資訊，請按一下<a href='https://aka.ms/vscodeJupyterKernelCrash'>這裡</a>。
#
# 如需詳細資料，請檢視 Jupyter <a href='command:jupyter.viewOutput'>記錄</a>。
