# %%
import matplotlib.pyplot as plt

labels=['Nokia','Samsung','Apple','Lumbia']
values = [20, 30, 40, 10]
colors = ['yellow', 'green', 'red', 'blue']
explode = (0, 0, 0.1, 0)
plt.pie(values,labels=labels)
plt.show()
